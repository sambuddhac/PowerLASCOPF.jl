# %%
# activate julia environment in a controlled way
julia_environment = "Julia_src/activate.jl"
include(julia_environment)
# Out:
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [7073ff75] + IJulia v1.26.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.2
#   [7073ff75] + IJulia v1.26.0
#   [692b3bcd] + JLLWrappers v1.7.0
#   [682c06a0] + JSON v0.21.4
#   [739be429] + MbedTLS v1.1.9
#   [69de0a69] + Parsers v2.8.1
#   [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [b85f4697] + SoftGlobalScope v1.1.0
#   [81def892] + VersionParsing v1.3.0
#   [c2297ded] + ZMQ v1.4.0
#   [8f1865be] + ZeroMQ_jll v4.3.5+3
#   [a9144af2] + libsodium_jll v1.0.20+3
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.10.0
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [deac9b47] + LibCURL_jll v8.4.0+0
#   [e37daf67] + LibGit2_jll v1.6.4+0
#   [29816b5a] + LibSSH2_jll v1.11.0+1
#   [c8ffd9c3] + MbedTLS_jll v2.28.2+1
#   [14a3606d] + MozillaCACerts_jll v2023.1.10
#   [83775a58] + Zlib_jll v1.2.13+1
#   [8e850ede] + nghttp2_jll v1.52.0+1
#   [3f19e933] + p7zip_jll v17.4.0+2
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.0
#   [34da2185] + Compat v4.16.0
#   [37e2e46d] + LinearAlgebra
#   [9abbd945] + Profile
#   [2f01184e] + SparseArrays v1.10.0
#   [10745b16] + Statistics v1.10.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.23+4
#   [bea87d4a] + SuiteSparse_jll v7.2.1+1
#   [8e850b90] + libblastrampoline_jll v5.8.0+1
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [336ed68f] + CSV v0.10.15
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [336ed68f] + CSV v0.10.15
#   [944b1d66] + CodecZlib v0.7.8
#   [9a962f9c] + DataAPI v1.16.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [48062228] + FilePathsBase v0.9.23
#   [842dd82b] + InlineStrings v1.4.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [bac558e1] + OrderedCollections v1.8.0
#   [2dfb63ee] + PooledArrays v1.4.3
#   [91c51154] + SentinelArrays v1.4.8
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.0
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
#   [9fa8497b] + Future
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.7.0
#   [864edb3b] + DataStructures v0.18.20
#   [41ab1584] + InvertedIndices v1.3.1
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [e1d29d7a] + Missings v1.2.0
#   [08abe8d2] + PrettyTables v2.4.0
#   [189a3867] + Reexport v1.2.2
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [892a3eda] + StringManipulation v0.4.1
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [864edb3b] + DataStructures v0.18.20
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [ade2ca70] + Dates
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [37e2e46d] + LinearAlgebra
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [b8f27783] + MathOptInterface v1.36.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [523fee87] + CodecBzip2 v0.8.5
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [f6369f11] + ForwardDiff v0.10.38
#   [92d709cd] + IrrationalConstants v0.2.4
#   [0f8b85d8] + JSON3 v1.14.1
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [1914dd2f] + MacroTools v0.5.15
#   [b8f27783] + MathOptInterface v1.36.0
#   [d8a4904e] + MutableArithmetics v1.6.3
#   [77ba4419] + NaNMath v1.1.2
#   [276daf66] + SpecialFunctions v2.5.0
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [856f2bd8] + StructTypes v1.11.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [05823500] + OpenLibm_jll v0.8.1+2
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [fdba3010] + MathProgBase v0.7.8
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [fdba3010] + MathProgBase v0.7.8
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [731186ca] + RecursiveArrayTools v3.29.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.41
#   [79e6a3ab] + Adapt v4.1.1
#   [4fba245c] + ArrayInterface v7.18.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [187b0558] + ConstructionBase v1.5.8
#   [e2ba6199] + ExprTools v0.1.10
#   [46192b85] + GPUArraysCore v0.2.0
#   [3587e190] + InverseFunctions v0.1.17
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [731186ca] + RecursiveArrayTools v3.29.0
#   [ae029012] + Requires v1.3.0
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.13
#   [2efcf032] + SymbolicIndexingInterface v0.3.37
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [10745b16] + Statistics v1.10.0
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [2913bbd2] + StatsBase v0.34.4
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [43287f4e] + PtrArrays v1.3.0
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.4
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [ddb6d928] + YAML v0.4.12
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [69024149] + StringEncodings v0.3.7
#   [ddb6d928] + YAML v0.4.12
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [91a5bcdd] + Plots v1.40.9
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.9
#   [35d6a980] + ColorSchemes v3.29.0
#   [3da002f7] + ColorTypes v0.12.0
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.0
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.13
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.15
#   [1019f520] + JLFzf v0.1.9
#   [23fbe1c1] + Latexify v0.16.6
#   [e6f89c97] + LoggingExtras v1.1.0
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.4.3
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.9
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.2
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.5.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.22.0
#   [45397f5d] + UnitfulLatexify v1.6.4
#   [41fe7b60] + Unzip v0.2.0
#   [83423d85] + Cairo_jll v1.18.2+1
#   [ee1fde0b] + Dbus_jll v1.14.10+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.15.0+0
#   [d7e528f0] + FreeType2_jll v2.13.3+1
#   [559328eb] + FriBidi_jll v1.0.16+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.13+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.82.4+0
#   [3b182d85] + Graphite2_jll v1.3.14+1
#   [2e76f6c2] + HarfBuzz_jll v8.5.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.7+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+2
#   [d4300ac3] + Libgcrypt_jll v1.11.0+0
#   [7e76a0d4] + Libglvnd_jll v1.7.0+0
#   [7add5ba3] + Libgpg_error_jll v1.51.1+0
#   [4b2f31a3] + Libmount_jll v2.40.3+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.40.3+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v3.0.16+0
#   [91d4177d] + Opus_jll v1.3.3+0
#   [36c8627f] + Pango_jll v1.56.1+0
# ⌅ [30392449] + Pixman_jll v0.43.4+0
# ⌅ [c0090381] + Qt6Base_jll v6.7.1+1
# ⌅ [629bc702] + Qt6Declarative_jll v6.7.1+2
# ⌅ [ce943373] + Qt6ShaderTools_jll v6.7.1+1
# ⌃ [e99dba38] + Qt6Wayland_jll v6.7.1+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.21.0+2
#   [2381bf8a] + Wayland_protocols_jll v1.36.0+0
#   [02c8fc9c] + XML2_jll v2.13.6+0
#   [aed1982a] + XSLT_jll v1.1.42+0
#   [ffd25f8a] + XZ_jll v5.6.4+1
#   [f67eecfb] + Xorg_libICE_jll v1.1.1+0
#   [c834827a] + Xorg_libSM_jll v1.2.4+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.6+3
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.12+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.3+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.5+0
#   [1082639a] + Xorg_libXext_jll v1.3.6+3
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.0+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.2+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.5+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.4+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.11+1
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.2+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.2+1
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.6+1
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.5.1+0
#   [3161d3a3] + Zstd_jll v1.5.7+0
#   [35ca27e7] + eudev_jll v3.2.9+0
#   [214eeab7] + fzf_jll v0.56.3+0
#   [1a1c6b14] + gperf_jll v3.1.1+1
#   [a4ae2306] + libaom_jll v3.11.0+0
#   [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.3+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.46+0
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.6+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+2
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ ColorSchemes
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   ✓ Plots → IJuliaExt
#   8 dependencies successfully precompiled in 84 seconds. 221 already precompiled.
#    Resolving package versions...
#    Installed MKL ─────────────────── v0.7.0
#    Installed AppleAccelerate ─────── v0.4.0
#    Installed PowerFlows ──────────── v0.8.0
#    Installed HydroPowerSimulations ─ v0.11.0
#    Installed PowerSimulations ────── v0.30.0
#    Installed PowerNetworkMatrices ── v0.12.1
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [fc1677e0] + HydroPowerSimulations v0.11.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [13e28ba4] + AppleAccelerate v0.4.0
#   [a74b3585] + Blosc v0.7.3
#   [a10d1c49] + DBInterface v2.6.1
#   [b4f34e82] + Distances v0.10.12
#   [6a86dc24] + FiniteDiff v2.27.0
#   [c8ec2601] + H5Zblosc v0.1.2
#   [f67ccb44] + HDF5 v0.17.2
#   [fc1677e0] + HydroPowerSimulations v0.11.0
#   [2030c09a] + InfrastructureModels v0.7.8
#   [2cd47ed4] + InfrastructureSystems v2.4.2
#   [4076af6c] + JuMP v1.24.0
#   [ef3ab10e] + KLU v0.6.0
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.2.0
#   [d3d80556] + LineSearches v7.3.0
# ⌅ [33e6dc65] + MKL v0.7.0
#   [3da0fdf6] + MPIPreferences v0.1.11
#   [f28f55f0] + Memento v1.4.1
#   [ffc61752] + Mustache v1.0.20
#   [d41bc354] + NLSolversBase v7.8.3
#   [2774e3e8] + NLsolve v4.5.1
#   [d96e819e] + Parameters v0.12.3
# ⌅ [46dd5b70] + Pardiso v0.5.7
#   [dd99e9e3] + PowerFlowData v1.5.0
#   [94fada2c] + PowerFlows v0.8.0
#   [c36e90e8] + PowerModels v0.21.3
#   [bed98974] + PowerNetworkMatrices v0.12.1
#   [e690365d] + PowerSimulations v0.30.0
#   [bcd98974] + PowerSystems v4.6.0
#   [33c8b6b6] + ProgressLogging v0.1.4
#   [92933f4c] + ProgressMeter v1.10.2
#   [0aa819cd] + SQLite v1.6.1
#   [efcf1570] + Setfield v1.1.1
#   [5d786b92] + TerminalLoggers v0.1.7
#   [9e3dc215] + TimeSeries v0.24.2
#   [a759f4b9] + TimerOutputs v0.5.26
#   [3a884ed6] + UnPack v1.0.2
#   [0b7ba130] + Blosc_jll v1.21.6+2
#   [0234f1f7] + HDF5_jll v1.14.3+3
#   [e33a78d0] + Hwloc_jll v2.11.2+3
# ⌅ [1d5cc7b8] + IntelOpenMP_jll v2024.2.1+0
#   [5ced341a] + Lz4_jll v1.10.1+0
# ⌅ [856f044c] + MKL_jll v2024.2.0+0
#   [7cb0a576] + MPICH_jll v4.2.3+0
#   [f1f71cc9] + MPItrampoline_jll v5.5.2+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+3
# ⌅ [fe0851c0] + OpenMPI_jll v4.1.6+0
#   [76ed43ae] + SQLite_jll v3.48.0+0
#   [477f73a3] + libaec_jll v1.1.3+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [8ba89e20] + Distributed
#   [4af54fe1] + LazyArtifacts
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ AppleAccelerate
#   ✓ MKL
#   ✓ HDF5_jll
#   ✓ HDF5
#   ✓ H5Zblosc
#   ✓ InfrastructureSystems
#   ✓ PowerSystems
#   ✓ PowerNetworkMatrices
#   ✓ PowerFlows
#   ✓ PowerSimulations
#   ✓ HydroPowerSimulations
#   11 dependencies successfully precompiled in 73 seconds. 272 already precompiled.
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [5c1252a2] + GeometryBasics v0.5.2
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [411431e0] + Extents v0.1.5
#   [68eda718] + GeoFormatTypes v0.4.4
#   [cf35fbd7] + GeoInterface v1.4.1
#   [5c1252a2] + GeometryBasics v0.5.2
#   [c8e1da08] + IterTools v1.10.0
#   [90137ffa] + StaticArrays v1.9.12
#   [5ae413db] + EarCut_jll v2.2.4+0
# Precompiling project...
#   ✓ Plots → GeometryBasicsExt
#   1 dependency successfully precompiled in 5 seconds. 296 already precompiled.
#    Resolving package versions...
#    Installed PowerSimulations ─ v0.29.2
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
# ⌃ [fc1677e0] ↓ HydroPowerSimulations v0.11.0 ⇒ v0.10.0
# ⌃ [bcd98974] + PowerSystems v4.4.1
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [13e28ba4] - AppleAccelerate v0.4.0
# ⌃ [fc1677e0] ↓ HydroPowerSimulations v0.11.0 ⇒ v0.10.0
# ⌅ [33e6dc65] ↓ MKL v0.7.0 ⇒ v0.6.3
#   [94fada2c] - PowerFlows v0.8.0
# ⌅ [bed98974] ↓ PowerNetworkMatrices v0.12.1 ⇒ v0.11.1
# ⌅ [e690365d] ↓ PowerSimulations v0.30.0 ⇒ v0.29.2
# ⌃ [bcd98974] ↓ PowerSystems v4.6.0 ⇒ v4.4.1
# ⌃ [0234f1f7] ↓ HDF5_jll v1.14.3+3 ⇒ v1.14.2+1
#   [fe0851c0] ↑ OpenMPI_jll v4.1.6+0 ⇒ v5.0.6+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ HDF5_jll
#   ✓ HDF5
#   ✓ H5Zblosc
#   ✓ InfrastructureSystems
#   ✓ PowerSystems
#   ✓ PowerNetworkMatrices
#   ✓ PowerSimulations
#   ✓ HydroPowerSimulations
#   8 dependencies successfully precompiled in 62 seconds. 287 already precompiled.
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
# ⌅ [e690365d] + PowerSimulations v0.29.1
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
# ⌅ [e690365d] ↓ PowerSimulations v0.29.2 ⇒ v0.29.1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ PowerSimulations
#   ✓ HydroPowerSimulations
#   2 dependencies successfully precompiled in 20 seconds. 293 already precompiled.
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [5f7eddb3] + PowerGraphics v0.19.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
# ⌅ [3da002f7] ↓ ColorTypes v0.12.0 ⇒ v0.11.5
# ⌃ [c3611d14] ↓ ColorVectorSpace v0.11.0 ⇒ v0.10.0
# ⌅ [5ae59095] ↓ Colors v0.13.0 ⇒ v0.12.11
# ⌅ [56ce1300] + PowerAnalytics v0.8.1
#   [5f7eddb3] + PowerGraphics v0.19.0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ ColorSchemes
#   ✓ PowerAnalytics
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   ✓ Plots → GeometryBasicsExt
#   ✓ Plots → IJuliaExt
#   ✓ PowerGraphics
#   11 dependencies successfully precompiled in 92 seconds. 286 already precompiled.
#   1 dependency had output during precompilation:
# ┌ PowerGraphics
# │  [ Info: PowerGraphics.jl loads Plots.jl. Precompile might take a while
# └
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
# ⌅ [56ce1300] + PowerAnalytics v0.8.1
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [2e9cd046] + Gurobi v1.6.2
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [2e9cd046] + Gurobi v1.6.2
#   [c018c7e6] + Gurobi_jll v12.0.0
# Precompiling project...
#   ✓ Gurobi
#   1 dependency successfully precompiled in 5 seconds. 298 already precompiled.
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [9e3dc215] + TimeSeries v0.24.2
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
# ⌃ [e2f1a126] + StorageSystemsSimulations v0.11.1
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
# ⌃ [e2f1a126] + StorageSystemsSimulations v0.11.1
#         Info Packages marked with ⌃ have new versions available and may be upgradable.
# Precompiling project...
#   ✓ StorageSystemsSimulations
#   1 dependency successfully precompiled in 9 seconds. 299 already precompiled.
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [5d317b1e] + GenX v0.4.4
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [aaaa29a8] + Clustering v0.15.8
#   [861a8166] + Combinatorics v1.0.2
#   [5d317b1e] + GenX v0.4.4
#   [87dc4568] + HiGHS v1.13.0
#   [b8a86587] + NearestNeighbors v0.4.21
#   [8fd58aa0] + HiGHS_jll v1.9.0+0
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [60bf3e95] + GLPK v1.2.1
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [60bf3e95] + GLPK v1.2.1
#   [e8aa6df9] + GLPK_jll v5.0.1+1
#   [781609d7] + GMP_jll v6.2.1+6
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [87dc4568] + HiGHS v1.13.0
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [b6b21f68] + Ipopt v1.7.2
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [b6b21f68] + Ipopt v1.7.2
#   [ae81ac8f] + ASL_jll v0.1.3+0
#   [9cc047cb] + Ipopt_jll v300.1400.1700+0
#   [d00139f3] + METIS_jll v5.1.3+0
#   [d7ed1dd3] + MUMPS_seq_jll v500.700.301+0
# ⌅ [656ef2d0] + OpenBLAS32_jll v0.3.24+0
# ⌅ [319450e9] + SPRAL_jll v2024.5.8+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [4076af6c] + JuMP v1.24.0
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#    Installed Ncurses_jll ── v6.5.1+0
#    Installed SCIP_jll ───── v900.200.100+0
#    Installed SCIP ───────── v0.12.3
#    Installed Readline_jll ─ v8.2.13+0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [82193955] + SCIP v0.12.3
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [82193955] + SCIP v0.12.3
# ⌅ [9cc047cb] ↓ Ipopt_jll v300.1400.1700+0 ⇒ v300.1400.1400+0
# ⌅ [d7ed1dd3] ↓ MUMPS_seq_jll v500.700.301+0 ⇒ v500.600.201+0
#   [68e3532b] + Ncurses_jll v6.5.1+0
#   [05236dd9] + Readline_jll v8.2.13+0
#   [fc9abe76] + SCIP_PaPILO_jll v900.200.0+0
#   [e5ac4fe4] + SCIP_jll v900.200.100+0
# ⌅ [319450e9] ↓ SPRAL_jll v2024.5.8+0 ⇒ v2024.1.18+0
#   [508c9074] + bliss_jll v0.77.0+1
# ⌅ [28df3c45] + boost_jll v1.79.0+3
# ⌅ [1317d2d5] ↓ oneTBB_jll v2022.0.0+0 ⇒ v2021.12.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#     Building SCIP → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/34fc53e96b77a9abb54d1303d1b0b8999e5c4514/build.log`
# Precompiling project...
#   ✓ MUMPS_seq_jll
#   ✓ Ncurses_jll
#   ✓ SPRAL_jll
#   ✓ Ipopt_jll
#   ✓ Readline_jll
#   ✓ SCIP_jll
#   ✓ SCIP_PaPILO_jll
#   ✓ Ipopt
# Activating the Julia virtual environment
#   ✓ SCIP
#   9 dependencies successfully precompiled in 18 seconds. 314 already precompiled.

# %%
Pkg.add("PowerModels")
Pkg.add("Ipopt")
Pkg.add("JuMP")
Pkg.add("Cbc")
Pkg.add("GLPK")
Pkg.add("PowerSystemCaseBuilder")
using Pkg; Pkg.status()
# Out:
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [c36e90e8] + PowerModels v0.21.3
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   [9961bab8] + Cbc v1.2.0
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#   [9961bab8] + Cbc v1.2.0
#   [38041ee0] + Cbc_jll v200.1000.800+0
#   [3830e938] + Cgl_jll v0.6000.600+0
# ⌅ [06985876] + Clp_jll v100.1700.700+1
# ⌅ [be027038] + CoinUtils_jll v200.1100.600+0
# ⌅ [7da25872] + Osi_jll v0.10800.700+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Clp_jll
#   ✓ Cgl_jll
#   ✓ Cbc_jll
#   ✓ Cbc
#   4 dependencies successfully precompiled in 9 seconds. 325 already precompiled.
#    Resolving package versions...
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   No Changes to `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
#    Resolving package versions...
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
# ⌃ [f00506e0] + PowerSystemCaseBuilder v1.3.10
#     Updating `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Manifest.toml`
# ⌃ [f00506e0] + PowerSystemCaseBuilder v1.3.10
#         Info Packages marked with ⌃ have new versions available and may be upgradable.
# Precompiling project...
# Status `~/code/OPF_LASCOPF_Staple/PowerLASCOPF/Project.toml`
#   ✓ PowerSystemCaseBuilder
#   1 dependency successfully precompiled in 8 seconds. 329 already precompiled.
#   [6e4b80f9] BenchmarkTools v1.6.0
#   [336ed68f] CSV v0.10.15
#   [9961bab8] Cbc v1.2.0
#   [a93c6f00] DataFrames v1.7.0
#   [864edb3b] DataStructures v0.18.20
#   [60bf3e95] GLPK v1.2.1
#   [5d317b1e] GenX v0.4.4
#   [5c1252a2] GeometryBasics v0.5.2
#   [2e9cd046] Gurobi v1.6.2
#   [87dc4568] HiGHS v1.13.0
# ⌃ [fc1677e0] HydroPowerSimulations v0.10.0
#   [7073ff75] IJulia v1.26.0
#   [b6b21f68] Ipopt v1.7.2
#   [4076af6c] JuMP v1.24.0
#   [b8f27783] MathOptInterface v1.36.0
#   [fdba3010] MathProgBase v0.7.8
#   [91a5bcdd] Plots v1.40.9
# ⌅ [56ce1300] PowerAnalytics v0.8.1
#   [5f7eddb3] PowerGraphics v0.19.0
#   [c36e90e8] PowerModels v0.21.3
# ⌅ [e690365d] PowerSimulations v0.29.1
# ⌃ [f00506e0] PowerSystemCaseBuilder v1.3.10
# ⌃ [bcd98974] PowerSystems v4.4.1
#   [731186ca] RecursiveArrayTools v3.29.0
#   [82193955] SCIP v0.12.3
#   [2913bbd2] StatsBase v0.34.4
# ⌃ [e2f1a126] StorageSystemsSimulations v0.11.1
#   [9e3dc215] TimeSeries v0.24.2
#   [ddb6d928] YAML v0.4.12
#   [ade2ca70] Dates
#   [37e2e46d] LinearAlgebra
#   [10745b16] Statistics v1.10.0
# Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated`

# %%
using PowerSystems
using PowerSimulations
using PowerGraphics
using PowerAnalytics
using HiGHS
using CSV
using MathOptInterface
using DataFrames
using TimeSeries
using Dates
using Statistics
using StorageSystemsSimulations
using Plots
using PowerModels
using PowerSystems
using PowerSimulations
using PowerGraphics
using PowerAnalytics
using StorageSystemsSimulations
using Plots
using InfrastructureSystems
using PowerSystemCaseBuilder
using GenX
using CSV
using DataFrames
using TimeSeries
using Dates
using Statistics
import GenX
import PowerData
import LazyArtifacts
import PowerSystemCaseBuilder: SystemCategory
import PowerSystems
import PowerSimulations
import PowerModels
import PowerModels: solve_ac_opf, solve_dc_opf, solve_opf, @im_fields, nw_id_default #Need to work further
import InfrastructureSystems
import InfrastructureModels
import InfrastructureModels: optimize_model!, @im_fields, nw_id_default


# Type Alias From other Packages
const _GX = GenX
const _PMod = PowerModels
const _PSys = PowerSystems
const _PSim = PowerSimulations
const _PG = PowerGraphics
const _PA = PowerAnalytics
const _SSim = StorageSystemsSimulations
const _Plots = Plots
const _ISys = InfrastructureSystems
const _IM = InfrastructureModels
const MOI = MathOptInterface
const MOIU = MathOptInterface.Utilities
const MOPFM = MOI.FileFormats.Model
const PNM = PowerNetworkMatrices
const TS = TimeSeries
const _PSYCB = PowerSystemCaseBuilder
# Out:
# [ Info: Precompiling PowerSystems [bcd98974-b02a-5e2f-9ee0-a103f5c450dd]
# ERROR: LoadError: ArgumentError: Platform `riscv64-linux-gnu` is not an officially supported platform
# Stacktrace:
#  [1] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String; validate_strict::Bool)
#    @ Base.BinaryPlatforms ./binaryplatforms.jl:753
#  [2] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String)
#    @ Base.BinaryPlatforms ./binaryplatforms.jl:671
#  [3] (::Libiconv_jll.var"#parse_wrapper_platform#1")(x::Any)
#    @ Libiconv_jll ~/.julia/packages/JLLWrappers/pG9bm/src/toplevel_generators.jl:113
#  [4] (::Libiconv_jll.var"#make_wrapper_dict#2"{Libiconv_jll.var"#parse_wrapper_platform#1"})(dir::Any, x::Any)
#    @ Libiconv_jll ~/.julia/packages/JLLWrappers/pG9bm/src/toplevel_generators.jl:145
#  [5] top-level scope
#    @ ~/.julia/packages/JLLWrappers/pG9bm/src/toplevel_generators.jl:160
#  [6] include
#    @ ./Base.jl:495 [inlined]
#  [7] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base ./loading.jl:2222
#  [8] top-level scope
#    @ stdin:3
# in expression starting at /Users/sc87/.julia/packages/Libiconv_jll/sE4g7/src/Libiconv_jll.jl:2
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile Libiconv_jll [94ce4f54-9a6c-5748-9c1c-f9c7231a4531] to "/Users/sc87/.julia/compiled/v1.10/Libiconv_jll/jl_KrwrKF".
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:2468
#   [3] compilecache
#     @ ./loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base ./loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:93
#   [6] #mkpidlock#6
#     @ ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:111
#   [8] #invokelatest#2
#     @ ./essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ ./essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ ./loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1812
#  [14] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1803
#  [17] macro expansion
#     @ ./loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ ./lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1753
#  [20] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1746
#  [23] include
#     @ ./Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base ./loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at /Users/sc87/.julia/packages/StringEncodings/unzPp/src/StringEncodings.jl:3
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile StringEncodings [69024149-9ee7-55f6-a4c4-859efe599b68] to "/Users/sc87/.julia/compiled/v1.10/StringEncodings/jl_xCTQaQ".
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:2468
#   [3] compilecache
#     @ ./loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base ./loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:93
#   [6] #mkpidlock#6
#     @ ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:111
#   [8] #invokelatest#2
#     @ ./essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ ./essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ ./loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1812
#  [14] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1803
#  [17] macro expansion
#     @ ./loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ ./lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1753
#  [20] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1746
#  [23] include
#     @ ./Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base ./loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at /Users/sc87/.julia/packages/YAML/XZZ1Y/src/YAML.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile YAML [ddb6d928-2868-570f-bddf-ab3f9cf99eb6] to "/Users/sc87/.julia/compiled/v1.10/YAML/jl_6pqeBl".
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:2468
#   [3] compilecache
#     @ ./loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base ./loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:93
#   [6] #mkpidlock#6
#     @ ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:111
#   [8] #invokelatest#2
#     @ ./essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ ./essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ ./loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1812
#  [14] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1803
#  [17] macro expansion
#     @ ./loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ ./lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1753
#  [20] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1746
#  [23] include
#     @ ./Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base ./loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at /Users/sc87/.julia/packages/PowerSystems/BOxsj/src/PowerSystems.jl:3
# in expression starting at stdin:3
# Failed to precompile PowerSystems [bcd98974-b02a-5e2f-9ee0-a103f5c450dd] to "/Users/sc87/.julia/compiled/v1.10/PowerSystems/jl_mlUpi1".
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base ./loading.jl:2468
#   [3] compilecache
#     @ ./loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base ./loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:93
#   [6] #mkpidlock#6
#     @ ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.10.4+0.x64.apple.darwin14/share/julia/stdlib/v1.10/FileWatching/src/pidfile.jl:111
#   [8] #invokelatest#2
#     @ ./essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ ./essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ ./loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1812
#  [14] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:1803
#  [17] macro expansion
#     @ ./loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ ./lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1753
#  [20] #invoke_in_world#3
#     @ ./essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ ./essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:1746
